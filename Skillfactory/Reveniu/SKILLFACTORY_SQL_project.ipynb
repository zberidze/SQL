# %% [markdown]
# В этом модуле мы предлагаем вам решить распространённую в сфере аналитики задачу — расчёт юнит-экономики. В ходе решения вы не только попрактикуетесь в получении нужных данных из базы данных, но и познакомитесь с процессом анализа этих данных.

# %% [markdown]
# Юнит-экономика (unit economics) — это метод экономического моделирования, используемый для определения прибыльности бизнес-модели путём оценки прибыльности единицы товара или одного клиента.

# %% [markdown]
# Юнит-экономика, как правило, применяется для оценки прибыльности бизнес-идеи стартапа. Бизнес может быть успешным, только если отдельная единица товара или услуги будет прибыльной.
#
# Прежде чем приступить к решению кейса, настоятельно рекомендуем вам ознакомиться со статьёй Юнит-экономика. Начало.

# %% [markdown]
# https://khanin.info/blog/85

# %% [markdown]
# Вы работаете аналитиком в довольно крупном магазине бытовой техники. Бизнес ведётся уже не первый год, и руководство (в лице CEO компании Генриха Леонидовича) подумывает о том, чтобы открыть вторую точку продаж в соседнем городе.
#
# Прежде чем броситься в пучину расширения бизнеса, необходимо ответить на два волнующих вопроса:
#
# Готова ли компания к такому шагу?
#
# Насколько эффективна существующая бизнес-модель?
#
# И отвечать на них предстоит вам!

# %% [markdown]
# Для этого потребуется проделать три шага:
#
# 1. Рассчитать среднее количество заказов на покупателя;
#
# 2. Определить средний чек и среднюю выручку с покупателя;
#
# 3. Рассчитать валовую выручку и прибыль.

# %% [markdown]
# Как мы будем работать?
#
# В рамках решения этой задачи мы будем получать данные из базы SQL, а Google Таблицы нам понадобятся для того, чтобы сохранять ответы, полученные с помощью SQL-запросов.
#
# Обратите внимание! Все примеры расчёта будут показаны на основе данных за март 2019 года. В расчёте своих показателей используйте данные за апрель 2019 г.

# %% [markdown]
# Каков будет результат?
#
# Вы рассчитаете все необходимые показатели юнит-экономики и на основе расчётов сделаете вывод о прибыльности экономики вашего предприятия. Вы оформите свои расчёты и вывод в Google Таблицах и в конце кейса узнаете, как работает компания — «в минус» или «в плюс».

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Таблицы, в которых хранятся нужные для этого кейса данные, хранятся в схеме case4, которую, как и в других модулях, вы найдёте в Metabase.
#
# Данные, хранящиеся в БД, имеют следующую структуру:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Введите запрос, позволяющий получить первые 10 строчек из таблицы order_session.
#
# Напоминаем, что в этом модуле мы обращаемся к таблицам схемы case4.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Давайте создадим в Google Таблицах файл, в который будем записывать наши показатели по мере их получения с помощью SQL-запросов.
#
# Для начала создайте таблицу с показателями, наподобие такой:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# А теперь перейдём к расчёту показателей на основе наших данных.
#
# Обратите внимание! В примерах приведены расчёты на основе данных за март 2019 года, а вам необходимо посчитать эти же показатели на основе данных за апрель 2019 года.

# %% [markdown]
# Первый показатель — пользователи. Тут всё просто: это количество уникальных пользователей, которые посетили наш сайт за нужный период времени.
#
# Давайте посмотрим на таблицу session и определим, как рассчитать количество пользователей.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Теперь рассчитаем, сколько пользователей пришло к нам в марте 2019 года.
#
# Для этого зададим следующий запрос:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сформируйте запрос к базе данных, который вернёт количество пользователей, пришедших в апреле 2019 года.
#
# Напоминаем, что в этом модуле мы обращамеся к таблицам схемы case4.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Итак, в марте 2019 года количество пользователей составляет 16403.
#
# Наша таблица юнит-экономики обзавелась первым показателем.
#
#
# ![image.png](data:image/png;base64,...)
#
# Помните, что вы рассчитываете показатели за апрель и ваши показатели будут другими.

# %% [markdown]
# КОЛИЧЕСТВО ЗАКАЗОВ (ORDERS)
# Для расчёта количества заказов, которые совершили пользователи, пришедшие в заданный период, нам понадобится объединить данные нескольких таблиц.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сформируйте запрос к базе данных, который вернёт количество заказов, совершённых пришедшими в апреле 2019 года пользователями.
#
# Напоминаем, что в этом модуле мы обращаемся к таблицам схемы case4.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ПОКУПАТЕЛИ (BUYERS)
#
# Следующее, что нам нужно узнать, — это сколько пользователей совершили уже посчитанные заказы, то есть количество покупателей.
#
# В дальнейшем этот показатель позволит нам понять, как часто эти покупатели совершают повторные покупки в конкретном месяце. Чтобы найти этот показатель, нужно лишь слегка модифицировать предыдущий запрос, с помощью которого мы получали количество заказов.

# %% [markdown]
# Сформируйте запрос к базе данных, который вернёт количество покупателей, совершивших заказы в апреле 2019 года.
#
# Напоминаем, что в этом модуле мы обращамеся к таблицам схемы case4. Рекомендуем перед отправкой кода проверить его работоспособность и соответствие условиям в Metabase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сформируйте запрос к базе данных, который вернёт объём выручки с заказов, совершённых в апреле 2019 года.
#
# Напоминаем, что в этом модуле мы обращамеся к таблицам схемы case4. Рекомендуем перед отправкой кода проверить его работоспособность и соответствие условиям в Metabase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Итак, теперь мы знаем средний чек для совершённых за месяц заказов.
#
# Далее нам нужно рассчитать показатель, который учитывает себестоимость нашего товара, — среднюю выручку с платящего пользователя.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Чтобы посчитать валовую выручку, мы умножили среднюю выручку с платящего пользователя на количество покупателей. Дальше нужно рассчитать стоимость привлечения пользователей в нашем периоде.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Сформируйте запрос к базе данных, который вернёт стоимость привлечения пользователей в апреле 2019 года.
#
# Напоминаем, что в этом модуле мы обращамеся к таблицам схемы case4. Рекомендуем перед отправкой кода проверить его работоспособность и соответствие условиям в Metabase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Остался последний и самый важный показатель в нашей юнит-экономике — прибыль.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Хранение дат в виде строк вместо чисел (например, хранение даты 20 марта 2019 года в виде строки '20.03.2019') встречается в БД достаточно часто. Несмотря на то что такой формат позволяет не потерять какую‐либо информацию, вы можете столкнуться с падением производительности. Во‐первых, если данные не хранятся как тип DATE, нельзя использовать для них функцию MONTH(). А еще не получится найти различия между двумя датами или минимальную дату в столбце.
#
# Эта проблема часто возникает, если вы загружаете данные в БД или очищаете её. Чем раньше вы сможете правильно отформатировать данные, тем проще будет проводить анализ. Можно исправить подобные ситуации, используя функции вроде CAST. При этом если вы загружаете данные с сотнями столбцов, где много таких, которыми вы никогда не воспользуетесь, возможно, не стоит тратить время на устранение всех проблем.

# %% [markdown]
# Вопрос о неправильном выборе типа хранения данных задают очень часто. Такое можно встретить не только в БД, но и в плоских файлах или в таблицах в средах R и Python. С помощью этого вопроса пытаются понять, считаете ли вы такие вещи нормой или нет, а еще хотят узнать, что вы будете делать, чтобы исправить ситуацию. Умение отвечать на подобные вопросы должно сформироваться естественным образом, если в ходе работы над проектом по анализу вам приходится чистить данные.
